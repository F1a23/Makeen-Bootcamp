# %%
"""The basic idea of analyzing the Zomato dataset is to get a fair idea about the factors affecting the aggregate rating of each restaurant, 
establishment of different types of restaurant at different places, Bengaluru being one such city has more than 12,000 restaurants 
with restaurants serving dishes from all over the world. With each day new restaurants opening the industry has'nt been saturated yet 
and the demand is increasing day by day. Inspite of increasing demand it however has become difficult for new restaurants to compete
with established restaurants. Most of them serving the same food. Bengaluru being an IT capital of India. Most of the people here 
are dependent mainly on the restaurant food as they don't have time to cook for themselves. With such an overwhelming demand of
restaurants it has therefore become important to study the demography of a location. What kind of a food is more popular in a locality.
Do the entire locality loves vegetarian food. If yes then is that locality populated by a particular sect of people for eg. Jain, Marwaris, 
Gujaratis who are mostly vegetarian. These kind of analysis can be done using the data, by studying different factors.
"""

# %%
#Zomato Bangalore Restaurants
#https://www.kaggle.com/datasets/himanshupoddar/zomato-bangalore-restaurants
import kagglehub

# Download latest version
path = kagglehub.dataset_download("himanshupoddar/zomato-bangalore-restaurants")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\USER PC\.cache\kagglehub\datasets\himanshupoddar\zomato-bangalore-restaurants\versions\1

# %%
import os
import pandas as pd

# Read the CSV file
csv_path = os.path.join(path, "zomato.csv")  
df = pd.read_csv(csv_path, encoding="latin1")

df.shape
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rishikeshkonapure/zomato")

print("Path to dataset files:", path)

import os
import pandas as pd

# Read the CSV file
csv_path = os.path.join(path, "zomato.csv")  
df = pd.read_csv(csv_path, encoding="latin1")

df.isnull().sum()
# Out:
# Path to dataset files: C:\Users\USER PC\.cache\kagglehub\datasets\rishikeshkonapure\zomato\versions\1
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
#10000 Restaurant Reviews
#https://www.kaggle.com/datasets/joebeachcapital/restaurant-reviews?select=Restaurant+reviews.csv
import kagglehub

# Download latest version
path = kagglehub.dataset_download("joebeachcapital/restaurant-reviews")

print("Path to dataset files:", path)

import os
import pandas as pd

# Read the CSV file
csv_path = os.path.join(path, "Restaurant reviews.csv")  
df = pd.read_csv(csv_path, encoding="latin1")

df.isnull().sum()
# Out:
# Path to dataset files: C:\Users\USER PC\.cache\kagglehub\datasets\joebeachcapital\restaurant-reviews\versions\1
# Restaurant       0
# Reviewer        38
# Review          45
# Rating          38
# Metadata        38
# Time            38
# Pictures         0
# 7514          9999
# dtype: int64

# %%
#Zomato Bangalore Restaurants 2022
#https://www.kaggle.com/datasets/vora1011/zomato-bangalore-restaurants-2022
#مش واجد مناسبة
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vora1011/zomato-bangalore-restaurants-2022")

print("Path to dataset files:", path)

import os
import pandas as pd

# Read the CSV file
csv_path = os.path.join(path, "BangaloreZomatoData.csv")  
df = pd.read_csv(csv_path, encoding="latin1")

df.head()
# Out:
# Path to dataset files: C:\Users\USER PC\.cache\kagglehub\datasets\vora1011\zomato-bangalore-restaurants-2022\versions\1
#                    Name                                                URL  \
# 0        Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
# 1         Meghana Foods  https://www.zomato.com/bangalore/meghana-foods...
# 2  Donne Biriyani House  https://www.zomato.com/bangalore/donne-biriyan...
# 3        Domino's Pizza  https://www.zomato.com/bangalore/dominos-pizza...
# 4                   KFC   https://www.zomato.com/bangalore/kfc-indiranagar
#
#                                             Cuisines                    Area  \
# 0  South Indian, North Indian, Chinese, Street Fo...  Indiranagar, Bangalore
# 1             Biryani, Andhra, North Indian, Seafood  Indiranagar, Bangalore
# 2                                            Biryani  Indiranagar, Bangalore
# 3                         Pizza, Fast Food, Desserts  Indiranagar, Bangalore
# ...

# %%
#Restaurants in Kochi ranked based on user ratings.
#https://www.kaggle.com/datasets/pravi21/restaurants-in-kochi-ranked-based-on-user-ratings
#مش واجد مناسبة
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pravi21/restaurants-in-kochi-ranked-based-on-user-ratings")

print("Path to dataset files:", path)

import os
import pandas as pd

# Read the CSV file
csv_path = os.path.join(path, "restaurants_in_kochi_ratings_and_rank.csv")  
df = pd.read_csv(csv_path, encoding="latin1")

df.isnull().sum()
# Out:
# Path to dataset files: C:\Users\USER PC\.cache\kagglehub\datasets\pravi21\restaurants-in-kochi-ranked-based-on-user-ratings\versions\1
# rank                 0
# name                 0
# review               1
# rated_excellent    140
# rated_very_good    140
# rated_average      140
# rated_poor         140
# rated_terrible     140
# rating             140
# price_range        876
# dtype: int64

# %%
#Riyadh Restaurants 20K
#https://www.kaggle.com/datasets/fahd09/riyadh-restaurants-20k
#فيها قيم باللغة العربية ومش ضابطة 

import kagglehub

# Download latest version
path = kagglehub.dataset_download("fahd09/riyadh-restaurants-20k")

print("Path to dataset files:", path)

import os
import pandas as pd

# Read the CSV file
csv_path = os.path.join(path, "riyadh_resturants_clean.csv")  
df = pd.read_csv(csv_path, encoding="latin1")

df.head()
# Out:
# Path to dataset files: C:\Users\USER PC\.cache\kagglehub\datasets\fahd09\riyadh-restaurants-20k\versions\1
#                                   name         categories  \
# 0       Ù
# Ø·Ø¹Ù
#  ÙÙØª Ø§ÙØ´ÙØ§ÙØ©  Afghan Restaurant
# 1              Ø¯ÙÙØ§ÙÙØ© Ø¹ÙØ§Ø¸              CafÃ©
# 2  Ø´Ø§ÙÙ Ø¬Ù
# Ø± Ø±Ø§Ø¹Ù Ø§ÙØ¬Ù
# Ø³        Coffee Shop
# 3                  ØºØ¯ÙØ± Ø§ÙØ´Ø§Ù
#   Afghan Restaurant
# 4                              Dunkin'         Donut Shop
#
#                                              address        lat        lng  \
# 0  Ø§ÙØ±ÙØ§Ø¶ 14723, Ø§ÙÙ
# Ù
# ÙÙØ© Ø§ÙØ¹Ø±Ø¨Ù...  24.518983  46.656981
# 1  Ø§ÙØ±ÙØ§Ø¶ 14726, Ø§ÙÙ
# Ù
# ÙÙØ© Ø§ÙØ¹Ø±Ø¨Ù...  24.518511  46.669149
# 2  Ø§ÙØ±ÙØ§Ø¶ 14726, Ø§ÙÙ
# Ù
# ÙÙØ© Ø§ÙØ¹Ø±Ø¨Ù...  24.519314  46.670041
# 3     Ø§ÙÙ
# Ù
# ÙÙØ© Ø§ÙØ¹Ø±Ø¨ÙØ© Ø§ÙØ³Ø¹ÙØ¯ÙØ©  24.519520  46.671660
# 4  Ø§ÙØ±ÙØ§Ø¶, Ø§ÙÙ
# Ù
# ÙÙØ© Ø§ÙØ¹Ø±Ø¨ÙØ© Ø§...  24.525001  46.433944
#
# ...

# %%
#Swiggy Indian Restraurant and Item Full Datasets
#https://www.kaggle.com/datasets/lokeshparab/swiggy-restraurant-and-item-full-datasets?select=Swiggy.csv
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lokeshparab/swiggy-restraurant-and-item-full-datasets")

print("Path to dataset files:", path)



# Read the CSV file
csv_path = os.path.join(path, "Swiggy.csv")  
df = pd.read_csv(csv_path, encoding="latin1")

df.isnull().sum()
# Out:
# Path to dataset files: C:\Users\USER PC\.cache\kagglehub\datasets\lokeshparab\swiggy-restraurant-and-item-full-datasets\versions\1
# C:\Users\USER PC\AppData\Local\Temp\ipykernel_5128\109142138.py:12: DtypeWarning: Columns (2,3,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, encoding="latin1")
# city                     0
# city link                0
# subcity            4630117
# subcity link       4630117
# restaurant code          0
# restaurant               0
# rating                   0
# rating count         25602
# cost                 29239
# address              25602
# cuisine                962
# licension no         40722
# restaurant link          0
# menu                 25602
# item                 25888
# price                  286
# veg_or_non_veg       25888
# dtype: int64
