# %%
#Deep Learning Assignment: The Fashion Classifier (MLP Edition)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.datasets import fashion_mnist # dataset 
from tensorflow.keras.utils import to_categorical
# Out:
# C:\Users\USER PC\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# Load dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Check shape before flattening
print("Before flattening:", X_train.shape)

# Normalize (0 - 1)---> sceling 
X_train = X_train / 255.0
X_test = X_test / 255.0

# Flatten images
X_train = X_train.reshape(X_train.shape[0], 784)
X_test = X_test.reshape(X_test.shape[0], 784)

# Check shape after flattening
print("After flattening:", X_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Before flattening: (60000, 28, 28)
# After flattening: (60000, 784)

# %%
class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

plt.figure(figsize=(12,5))
for i in range(10):
    idx = np.where(y_train == i)[0][0]
    plt.subplot(2,5,i+1)
    plt.imshow(X_train[idx].reshape(28,28), cmap='gray')
    plt.title(class_names[i])
    plt.axis('off')
plt.show()

# %%
#Task 1: Shallow Baseline Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
shallow_model = Sequential([
    Dense(32, activation='sigmoid', input_shape=(784,)),
    Dense(10, activation='softmax')
])

shallow_model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# C:\Users\USER PC\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#train
history_shallow = shallow_model.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.5551 - loss: 1.6362 - val_accuracy: 0.6886 - val_loss: 1.2102
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7106 - loss: 1.0425 - val_accuracy: 0.7293 - val_loss: 0.9044
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7396 - loss: 0.8409 - val_accuracy: 0.7507 - val_loss: 0.7736
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7575 - loss: 0.7419 - val_accuracy: 0.7667 - val_loss: 0.7014
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7697 - loss: 0.6815 - val_accuracy: 0.7774 - val_loss: 0.6528
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.7832 - loss: 0.6391 - val_accuracy: 0.7865 - val_loss: 0.6180
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7935 - loss: 0.6067 - val_accuracy: 0.7956 - val_loss: 0.5894
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8026 - loss: 0.5806 - val_accuracy: 0.8077 - val_loss: 0.5692
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8105 - loss: 0.5592 - val_accuracy: 0.8127 - val_loss: 0.5494
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8165 - loss: 0.5414 - val_accuracy: 0.8175 - val_loss: 0.5344

# %%
#evaluation
test_loss, test_acc = shallow_model.evaluate(X_test, y_test)
print("Shallow Model Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8072 - loss: 0.5566
# Shallow Model Test Accuracy: 0.807200014591217

# %%
#Task 2: Deep & Wide Model

deep_model = Sequential([
    Dense(512, activation='relu', input_shape=(784,)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

deep_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#train
history_deep = deep_model.fit(
    X_train, y_train,
    epochs=20,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.8206 - loss: 0.4963 - val_accuracy: 0.8502 - val_loss: 0.4137
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - accuracy: 0.8618 - loss: 0.3753 - val_accuracy: 0.8586 - val_loss: 0.3845
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8767 - loss: 0.3340 - val_accuracy: 0.8713 - val_loss: 0.3464
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.8850 - loss: 0.3087 - val_accuracy: 0.8849 - val_loss: 0.3194
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8925 - loss: 0.2921 - val_accuracy: 0.8779 - val_loss: 0.3348
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 36s 24ms/step - accuracy: 0.8957 - loss: 0.2762 - val_accuracy: 0.8837 - val_loss: 0.3201
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - accuracy: 0.9004 - loss: 0.2620 - val_accuracy: 0.8844 - val_loss: 0.3210
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9060 - loss: 0.2498 - val_accuracy: 0.8882 - val_loss: 0.3166
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 39s 18ms/step - accuracy: 0.9078 - loss: 0.2411 - val_accuracy: 0.8863 - val_loss: 0.3200
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 44s 20ms/step - accuracy: 0.9140 - loss: 0.2289 - val_accuracy: 0.8928 - val_loss: 0.3176
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9172 - loss: 0.2191 - val_accuracy: 0.8929 - val_loss: 0.3106
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9183 - loss: 0.2139 - val_accuracy: 0.8889 - val_loss: 0.3275
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.9205 - loss: 0.2055 - val_accuracy: 0.8895 - val_loss: 0.3530
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.9240 - loss: 0.1965 - val_accuracy: 0.8920 - val_loss: 0.3458
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9264 - loss: 0.1905 - val_accuracy: 0.8901 - val_loss: 0.3475
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9281 - loss: 0.1859 - val_accuracy: 0.8913 - val_loss: 0.3682
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9308 - loss: 0.1789 - val_accuracy: 0.8928 - val_loss: 0.3428
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9328 - loss: 0.1727 - val_accuracy: 0.8928 - val_loss: 0.3465
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 16ms/step - accuracy: 0.9348 - loss: 0.1696 - val_accuracy: 0.8844 - val_loss: 0.3898
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.9361 - loss: 0.1688 - val_accuracy: 0.8908 - val_loss: 0.3656

# %%
#evaluation
test_loss, test_acc = deep_model.evaluate(X_test, y_test)
print("Deep Model Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8793 - loss: 0.4069
# Deep Model Test Accuracy: 0.8792999982833862

# %%
#Task 3: Fighting Overfitting

plt.plot(history_deep.history['loss'], label='Train Loss')
plt.plot(history_deep.history['val_loss'], label='Val Loss')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
regularized_model = Sequential([
    Dense(512, activation='relu', input_shape=(784,)),
    Dropout(0.2),  # before it was 0.3 change to see if there any difrenet
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

regularized_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
#train
history_reg = regularized_model.fit(
    X_train, y_train,
    epochs=30,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.7946 - loss: 0.5707 - val_accuracy: 0.8470 - val_loss: 0.4172
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8444 - loss: 0.4249 - val_accuracy: 0.8622 - val_loss: 0.3810
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.8582 - loss: 0.3887 - val_accuracy: 0.8630 - val_loss: 0.3741
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.8642 - loss: 0.3692 - val_accuracy: 0.8761 - val_loss: 0.3427
# Epoch 5/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 32s 21ms/step - accuracy: 0.8726 - loss: 0.3500 - val_accuracy: 0.8751 - val_loss: 0.3391
# Epoch 6/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 32s 21ms/step - accuracy: 0.8753 - loss: 0.3394 - val_accuracy: 0.8706 - val_loss: 0.3608
# Epoch 7/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.8802 - loss: 0.3266 - val_accuracy: 0.8846 - val_loss: 0.3233
# Epoch 8/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 31s 21ms/step - accuracy: 0.8821 - loss: 0.3173 - val_accuracy: 0.8743 - val_loss: 0.3553
# Epoch 9/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.8880 - loss: 0.3054 - val_accuracy: 0.8845 - val_loss: 0.3372
# Epoch 10/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.8901 - loss: 0.2991 - val_accuracy: 0.8854 - val_loss: 0.3186
# Epoch 11/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.8915 - loss: 0.2958 - val_accuracy: 0.8888 - val_loss: 0.3188
# Epoch 12/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.8944 - loss: 0.2893 - val_accuracy: 0.8868 - val_loss: 0.3239
# Epoch 13/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 38s 21ms/step - accuracy: 0.8971 - loss: 0.2785 - val_accuracy: 0.8898 - val_loss: 0.3092
# Epoch 14/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 36s 24ms/step - accuracy: 0.8975 - loss: 0.2813 - val_accuracy: 0.8923 - val_loss: 0.3128
# Epoch 15/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.8995 - loss: 0.2705 - val_accuracy: 0.8857 - val_loss: 0.3249
# Epoch 16/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.9002 - loss: 0.2712 - val_accuracy: 0.8888 - val_loss: 0.3143

# %%
#Task 4: Forensic Analysis
from sklearn.metrics import confusion_matrix

# %%
y_pred = np.argmax(regularized_model.predict(X_test), axis=1)

cm = confusion_matrix(y_test, y_pred)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
#Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
#Displaying images that are incorrectly categorized

misclassified = np.where(y_test != y_pred)[0][:3]

plt.figure(figsize=(10,3))
for i, idx in enumerate(misclassified):
    plt.subplot(1,3,i+1)
    plt.imshow(X_test[idx].reshape(28,28), cmap='gray')
    plt.title(f"Predicted: {class_names[y_pred[idx]]}\nActual: {class_names[y_test[idx]]}")
    plt.axis('off')
plt.show()

# %%
#Bonus: Batch Size Experiment
# Batch Size = 32
regularized_model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Batch Size = 1024
regularized_model.fit(X_train, y_train, epochs=10, batch_size=1024, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 33s 22ms/step - accuracy: 0.8954 - loss: 0.2817 - val_accuracy: 0.8921 - val_loss: 0.3098
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 18ms/step - accuracy: 0.9002 - loss: 0.2733 - val_accuracy: 0.8875 - val_loss: 0.3126
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 31s 21ms/step - accuracy: 0.9015 - loss: 0.2677 - val_accuracy: 0.8894 - val_loss: 0.3256
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.9011 - loss: 0.2669 - val_accuracy: 0.8840 - val_loss: 0.3319
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.9032 - loss: 0.2631 - val_accuracy: 0.8944 - val_loss: 0.3035
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 32s 22ms/step - accuracy: 0.9046 - loss: 0.2564 - val_accuracy: 0.8840 - val_loss: 0.3299
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 31s 21ms/step - accuracy: 0.9058 - loss: 0.2542 - val_accuracy: 0.8894 - val_loss: 0.3144
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.9072 - loss: 0.2489 - val_accuracy: 0.8913 - val_loss: 0.3169
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.9085 - loss: 0.2465 - val_accuracy: 0.8911 - val_loss: 0.3233
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 32s 21ms/step - accuracy: 0.9068 - loss: 0.2467 - val_accuracy: 0.8933 - val_loss: 0.3104
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9204 - loss: 0.2109 - val_accuracy: 0.8989 - val_loss: 0.2958
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9254 - loss: 0.1962 - val_accuracy: 0.9014 - val_loss: 0.2951
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9283 - loss: 0.1905 - val_accuracy: 0.9014 - val_loss: 0.2967
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9287 - loss: 0.1876 - val_accuracy: 0.9018 - val_loss: 0.2977
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9292 - loss: 0.1848 - val_accuracy: 0.9009 - val_loss: 0.2998
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9301 - loss: 0.1836 - val_accuracy: 0.9015 - val_loss: 0.2995
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.9308 - loss: 0.1806 - val_accuracy: 0.9031 - val_loss: 0.3019
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9307 - loss: 0.1812 - val_accuracy: 0.9017 - val_loss: 0.3017
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9309 - loss: 0.1788 - val_accuracy: 0.9015 - val_loss: 0.3025
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9313 - loss: 0.1790 - val_accuracy: 0.9012 - val_loss: 0.3039

# %%
misclassified = np.where(y_test != y_pred)[0][:3]

plt.figure(figsize=(10,3))
for i, idx in enumerate(misclassified):
    ax = plt.subplot(1,3,i+1)
    ax.imshow(X_test[idx].reshape(28,28), cmap='viridis')  # لون الصورة
    
    ax.set_title(
        f"Predicted: {class_names[y_pred[idx]]}\nActual: {class_names[y_test[idx]]}",
        color="red"
    )
    ax.axis('off')
    
    # إطار ملون حول الصورة
    for spine in ax.spines.values():
        spine.set_visible(True)
        spine.set_edgecolor("red")
        spine.set_linewidth(3)

plt.show()
