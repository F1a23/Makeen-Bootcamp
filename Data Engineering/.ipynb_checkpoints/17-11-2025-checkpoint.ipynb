# %%
import pymysql
import pandas as pd
from datetime import datetime

# %%
# -------------------------------
# Sample data to store in MySQL
# -------------------------------
data = pd.DataFrame({
    "customer_id": ["C001", "C002", "C003", "C004", "C005"],
    "product": ["Laptop", "Mouse", "Keyboard", "Monitor", "Printer"],
    "quantity": [1, 2, 1, 3, 1],
    "timestamp": [
        "2025-11-16 10:15:00",
        "2025-11-16 11:20:00",
        "2025-11-16 12:30:00",
        "2025-11-16 13:45:00",
        "2025-11-16 14:50:00"
    ],
    "store": ["Muscat Store", "Seeb Store", "Salalah Store", "Nizwa Store", "Sohar Store"]
})

# %%
# -------------------------------
# Connect to MySQL database
# -------------------------------
central_db_connection = pymysql.connect(
    host="localhost",       # replace with your host
    user="root",            # replace with your MySQL username
    password="Oman99690050#",    # replace with your MySQL password
    database="pythonDB"   # replace with your database name
)

cursor = central_db_connection.cursor()

# %%
# -------------------------------
# Create table if it doesn't exist
# -------------------------------
create_table_query = """
CREATE TABLE IF NOT EXISTS consolidated_transactions (
    id INT AUTO_INCREMENT PRIMARY KEY,
    customer_id VARCHAR(255),
    product VARCHAR(255),
    quantity INT,
    timestamp DATETIME,
    store VARCHAR(255)
);
"""
cursor.execute(create_table_query)
# Out:
# 0

# %%
# -------------------------------
# Insert data into MySQL table
# -------------------------------
insert_query = """
INSERT INTO consolidated_transactions (customer_id, product, quantity, timestamp, store)
VALUES (%s, %s, %s, %s, %s);
"""

for _, row in data.iterrows():
    cursor.execute(insert_query, tuple(row))

central_db_connection.commit()
central_db_connection.close()

print("Data successfully stored in the central MySQL database.")
# Out:
# Data successfully stored in the central MySQL database.

# %%
----

# %%
import pymysql
import pandas as pd
from datetime import datetime

# -------------------------------
# Sample weather data (from API or manually)
# -------------------------------
data = pd.DataFrame({
    "city": ["Muscat", "Seeb", "Salalah", "Nizwa", "Sohar"],
    "temperature_c": [29.5, 28.0, 26.3, 24.8, 27.1],
    "feels_like_c": [31.0, 29.1, 27.0, 25.2, 28.0],
    "humidity": [60, 55, 70, 50, 65],
    "description": ["clear sky", "few clouds", "light rain", "sunny", "cloudy"],
    "wind_speed": [3.2, 2.5, 4.1, 1.8, 3.0],
    "timestamp": [
        "2025-11-16 10:00:00",
        "2025-11-16 10:05:00",
        "2025-11-16 10:10:00",
        "2025-11-16 10:15:00",
        "2025-11-16 10:20:00"
    ]
})

# -------------------------------
# Connect to MySQL database
# -------------------------------
connection = pymysql.connect(
    host="localhost",
    user="root",
    password="Oman99690050#",
    database="pythondb"     # <-- غيّري الاسم إذا تبين
)

cursor = connection.cursor()

# -------------------------------
# Create table if it doesn't exist
# -------------------------------
create_table_query = """
CREATE TABLE IF NOT EXISTS weather_reports (
    id INT AUTO_INCREMENT PRIMARY KEY,
    city VARCHAR(255),
    temperature_c FLOAT,
    feels_like_c FLOAT,
    humidity INT,
    description VARCHAR(255),
    wind_speed FLOAT,
    timestamp DATETIME
);
"""
cursor.execute(create_table_query)

# -------------------------------
# Insert data into MySQL table
# -------------------------------
insert_query = """
INSERT INTO weather_reports (city, temperature_c, feels_like_c, humidity, description, wind_speed, timestamp)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

for _, row in data.iterrows():
    cursor.execute(insert_query, tuple(row))

connection.commit()
connection.close()

print("Weather data successfully stored in the MySQL database.")
# Out:
# Weather data successfully stored in the MySQL database.

# %%
import pymysql
import pandas as pd
from datetime import datetime

# -------------------------------
# Read weather data from Excel file
# -------------------------------
file_path = "weather_report.xlsx"   # ضع الملف بجانب السكربت نفسه
data = pd.read_excel(file_path)

# -------------------------------
# Connect to MySQL database
# -------------------------------
connection = pymysql.connect(
    host="localhost",
    user="root",
    password="Oman99690050#",
    database="pythondb"
)

cursor = connection.cursor()

# -------------------------------
# Create table if it doesn't exist
# -------------------------------
create_table_query = """
CREATE TABLE IF NOT EXISTS weather_reports (
    id INT AUTO_INCREMENT PRIMARY KEY,
    city VARCHAR(255),
    temperature_c FLOAT,
    feels_like_c FLOAT,
    humidity INT,
    description VARCHAR(255),
    wind_speed FLOAT,
    timestamp DATETIME
);
"""
cursor.execute(create_table_query)

# -------------------------------
# Insert data into MySQL table
# -------------------------------
insert_query = """
INSERT INTO weather_reports (city, temperature_c, feels_like_c, humidity, description, wind_speed, timestamp)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

for _, row in data.iterrows():
    cursor.execute(insert_query, (
        row["city"],
        row["temperature_c"],
        row["feels_like_c"],
        row["humidity"],
        row["description"],
        row["wind_speed"],
        row["timestamp"]
    ))

connection.commit()
connection.close()

print("Weather data successfully stored in the MySQL database.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 9
#       5 # -------------------------------
#       6 # Read weather data from Excel file
#       7 # -------------------------------
#       8 file_path = "weather_report.xlsx"   # ضع الملف بجانب السكربت نفسه
# ----> 9 data = pd.read_excel(file_path)
#      11 # -------------------------------
#      12 # Connect to MySQL database
#      13 # -------------------------------
#      14 connection = pymysql.connect(
#      15     host="localhost",
#      16     user="root",
#      17     password="Oman99690050#",
#      18     database="pythondb"
#      19 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_report.xlsx'
